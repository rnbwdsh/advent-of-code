# %%
import re
import copy

a = """Immune System:
17 units each with 5390 hit points (weak to radiation, bludgeoning) with
 an attack that does 4507 fire damage at initiative 2
989 units each with 1274 hit points (immune to fire; weak to bludgeoning,
 slashing) with an attack that does 25 slashing damage at initiative 3

Infection:
801 units each with 4706 hit points (weak to radiation) with an attack
 that does 116 bludgeoning damage at initiative 1
4485 units each with 2961 hit points (immune to radiation; weak to fire,
 cold) with an attack that does 12 slashing damage at initiative 4"""
a = open("day24.txt").read()

class Team:
    def __init__(self, desc, name, boost=0):
        groupstr = desc.split("\n")
        self.groups = {i+1: Group(g, name+" group "+str(i+1)) for i, g in enumerate(groupstr)}
        self.name = name
        for g in self.groups.values():
            g.dmg += boost

    def print_status(self):
        print(self.name+":")
        for group_id, group in self.groups.items():
            print("Group",group_id,"contains",group.units,"units")

    def get_units(self):
        return sum([g.units for g in self.groups.values()])

    def final(self):
        return self.name+" remaining units "+str(self.get_units())

    def target_selection(self, other):
        targets = copy.deepcopy(other.groups)
        ordered_groups = sorted(self.groups.items(), key = lambda g: g[1].getPowerIniSort(), reverse=True)
        for group_id, group in ordered_groups:
            if len(targets) == 0: break #happens if all targets popped
            target_id, target = max(targets.items(), key=lambda t: t[1].get_damage_taken_eff_pow_ini(group.get_effective_power(), group.dmgtype)) #get best target
            log_dmg = target.get_damage_taken(group.get_effective_power(), group.dmgtype) #damage you'd do, just for logging
            if log_dmg == 0: continue # if you do 0 damage, don't pick that target
            print(self.name,"group",group_id,"would deal defending group", target_id, log_dmg, "damage")
            group.next_target = other.groups[target_id] # set next target
            targets.pop(target_id) # remove from options

    def cleanup(self):
        # filter dict like https://stackoverflow.com/questions/2844516/how-to-filter-a-dictionary-according-to-an-arbitrary-condition-function
        # kick out no-unit-groups
        self.groups = {k: v for k, v in self.groups.items() if v.units > 0}

class Group:
    def __init__(self, desc, name):
        self.name = name
        print(desc)
        numbers = re.findall(r"\d+", desc)
        numbers = [int(nr) for nr in numbers]
        self.units, self.hp, self.dmg, self.ini = numbers
        self.weak = re.findall(r"weak to (.+)\)", desc)
        if self.weak:
            # hotfix for parsing issue
            self.weak = re.sub(r";.+","", self.weak[0])
            self.weak = self.weak.split(", ")
        self.immune = re.findall(r"immune to (.+)\)", desc)
        if self.immune:
            self.immune = re.sub(r";.+","", self.immune[0])
            self.immune = self.immune.split(", ")
        self.dmgtype = re.findall(r"does \d+ (.+) damage", desc)[0]
        self.next_target = None
        print(self)

    def get_effective_power(self):
        return self.units * self.dmg

    def __repr__(self):
        return str(["name", self.name, \
                        "units",self.units, "hp",self.hp, \
                        "dmg",self.dmg, "ini",self.ini, \
                        "weak",self.weak, "immune",self.immune, "dmgtype",self.dmgtype])

    # needed for sorting who attacks first
    def getPowerIniSort(self):
        return (self.get_effective_power(), self.ini)

    # needed for sorting who gets targeted first
    def get_damage_taken_eff_pow_ini(self, effectivePower, dmgtype):
        dt = self.get_damage_taken(effectivePower, dmgtype)
        return (dt, self.get_effective_power(), self.ini)

    def get_damage_taken(self, effectivePower, dmgtype):
        # By default, an attacking group would deal damage equal to its effective power to the defending group. 
        # However, if the defending group is immune to the attacking group's attack type, the defending group 
        # instead takes no damage; if the defending group is weak to the attacking group's attack type, 
        # the defending group instead takes double damage.
        if dmgtype in self.weak:
            return effectivePower*2
        elif dmgtype in self.immune:
            return 0
        else:
            return effectivePower

    def attack(self):
        if self.next_target == None:
            return
        dmg = self.next_target.get_damage_taken(self.get_effective_power(), self.dmgtype)
        # int division. 531 dmg only kill 5 units with 100 health
        killed_units = dmg // self.next_target.hp
        killed_units = min(killed_units, self.next_target.units)
        self.next_target.units -= killed_units
        print(self.name,"attacks",self.next_target.name,"killing",killed_units,"units")
        self.next_target, self.next_damage = None, 0 # so we don't attack a team without selecting it

immu, infec = a.strip().replace("Immune System:\n","").replace("\n ", " ").split("\n\nInfection:\n")

# %%
immuT = Team(immu, "Immune system")
infecT = Team(infec, "Infection")
last_units = 0

while immuT.get_units() > 0 and infecT.get_units() > 0:
    # status phase    
    immuT.print_status()
    infecT.print_status()
    print()

    # target phase
    infecT.target_selection(immuT)
    immuT.target_selection(infecT)
    print()

    # attack phase
    # get team with biggest ini first
    tgroups = [*infecT.groups.values(), *immuT.groups.values()]
    tgroups = sorted(tgroups, key=lambda g: g.ini, reverse=True)
    for group in tgroups:
        group.attack()
    print()

    # cleanup phase: delete groups with 0 units
    infecT.cleanup()
    immuT.cleanup()

    units = infecT.get_units() + immuT.get_units()
    if last_units == units:
        print("no progress made, exiting this try")
        break
    last_units = units
# Out:
# 3115 units each with 1585 hit points (weak to slashing, bludgeoning) with an attack that does 4 slashing damage at initiative 7
# ['name', 'Immune system group 1', 'units', 3115, 'hp', 1585, 'dmg', 4, 'ini', 7, 'weak', ['slashing', 'bludgeoning'], 'immune', [], 'dmgtype', 'slashing']
# 3866 units each with 6411 hit points (weak to cold, radiation; immune to fire) with an attack that does 14 slashing damage at initiative 11
# ['name', 'Immune system group 2', 'units', 3866, 'hp', 6411, 'dmg', 14, 'ini', 11, 'weak', ['cold', 'radiation'], 'immune', ['fire'], 'dmgtype', 'slashing']
# 40 units each with 10471 hit points (weak to bludgeoning, slashing; immune to cold) with an attack that does 2223 cold damage at initiative 3
# ['name', 'Immune system group 3', 'units', 40, 'hp', 10471, 'dmg', 2223, 'ini', 3, 'weak', ['bludgeoning', 'slashing'], 'immune', ['cold'], 'dmgtype', 'cold']
# 1923 units each with 2231 hit points (weak to slashing, fire) with an attack that does 10 bludgeoning damage at initiative 13
# ['name', 'Immune system group 4', 'units', 1923, 'hp', 2231, 'dmg', 10, 'ini', 13, 'weak', ['slashing', 'fire'], 'immune', [], 'dmgtype', 'bludgeoning']
# 4033 units each with 10164 hit points (immune to slashing) with an attack that does 22 radiation damage at initiative 5
# ['name', 'Immune system group 5', 'units', 4033, 'hp', 10164, 'dmg', 22, 'ini', 5, 'weak', [], 'immune', ['slashing'], 'dmgtype', 'radiation']
# 36 units each with 5938 hit points (weak to bludgeoning, cold; immune to fire) with an attack that does 1589 slashing damage at initiative 4
# ['name', 'Immune system group 6', 'units', 36, 'hp', 5938, 'dmg', 1589, 'ini', 4, 'weak', ['bludgeoning', 'cold'], 'immune', ['fire'], 'dmgtype', 'slashing']
# 2814 units each with 7671 hit points (weak to cold) with an attack that does 21 radiation damage at initiative 15
# ['name', 'Immune system group 7', 'units', 2814, 'hp', 7671, 'dmg', 21, 'ini', 15, 'weak', ['cold'], 'immune', [], 'dmgtype', 'radiation']
# 217 units each with 9312 hit points (immune to slashing) with an attack that does 345 radiation damage at initiative 8
# ['name', 'Immune system group 8', 'units', 217, 'hp', 9312, 'dmg', 345, 'ini', 8, 'weak', [], 'immune', ['slashing'], 'dmgtype', 'radiation']
# 38 units each with 7686 hit points (weak to bludgeoning) with an attack that does 1464 radiation damage at initiative 14
# ['name', 'Immune system group 9', 'units', 38, 'hp', 7686, 'dmg', 1464, 'ini', 14, 'weak', ['bludgeoning'], 'immune', [], 'dmgtype', 'radiation']
# 5552 units each with 3756 hit points (weak to slashing) with an attack that does 6 fire damage at initiative 10
# ['name', 'Immune system group 10', 'units', 5552, 'hp', 3756, 'dmg', 6, 'ini', 10, 'weak', ['slashing'], 'immune', [], 'dmgtype', 'fire']
# 263 units each with 28458 hit points (weak to fire, radiation) with an attack that does 186 cold damage at initiative 9
# ['name', 'Infection group 1', 'units', 263, 'hp', 28458, 'dmg', 186, 'ini', 9, 'weak', ['fire', 'radiation'], 'immune', [], 'dmgtype', 'cold']
# 137 units each with 29425 hit points (immune to fire; weak to cold) with an attack that does 367 radiation damage at initiative 1
# ['name', 'Infection group 2', 'units', 137, 'hp', 29425, 'dmg', 367, 'ini', 1, 'weak', ['cold'], 'immune', ['fire'], 'dmgtype', 'radiation']
# 2374 units each with 41150 hit points (immune to bludgeoning, slashing, radiation; weak to cold) with an attack that does 34 bludgeoning damage at initiative 6
# ['name', 'Infection group 3', 'units', 2374, 'hp', 41150, 'dmg', 34, 'ini', 6, 'weak', ['cold'], 'immune', ['bludgeoning', 'slashing', 'radiation'], 'dmgtype', 'bludgeoning']
# 1287 units each with 24213 hit points (immune to fire) with an attack that does 36 cold damage at initiative 17
# ['name', 'Infection group 4', 'units', 1287, 'hp', 24213, 'dmg', 36, 'ini', 17, 'weak', [], 'immune', ['fire'], 'dmgtype', 'cold']
# 43 units each with 32463 hit points (weak to radiation; immune to slashing, bludgeoning) with an attack that does 1347 fire damage at initiative 16
# ['name', 'Infection group 5', 'units', 43, 'hp', 32463, 'dmg', 1347, 'ini', 16, 'weak', ['radiation'], 'immune', ['slashing', 'bludgeoning'], 'dmgtype', 'fire']
# 140 units each with 51919 hit points (weak to slashing, bludgeoning) with an attack that does 633 fire damage at initiative 12
# ['name', 'Infection group 6', 'units', 140, 'hp', 51919, 'dmg', 633, 'ini', 12, 'weak', ['slashing', 'bludgeoning'], 'immune', [], 'dmgtype', 'fire']
# 3814 units each with 33403 hit points with an attack that does 15 fire damage at initiative 19
# ['name', 'Infection group 7', 'units', 3814, 'hp', 33403, 'dmg', 15, 'ini', 19, 'weak', [], 'immune', [], 'dmgtype', 'fire']
# 3470 units each with 44599 hit points (weak to slashing, radiation) with an attack that does 23 radiation damage at initiative 18
# ['name', 'Infection group 8', 'units', 3470, 'hp', 44599, 'dmg', 23, 'ini', 18, 'weak', ['slashing', 'radiation'], 'immune', [], 'dmgtype', 'radiation']
# 394 units each with 36279 hit points with an attack that does 164 fire damage at initiative 20
# ['name', 'Infection group 9', 'units', 394, 'hp', 36279, 'dmg', 164, 'ini', 20, 'weak', [], 'immune', [], 'dmgtype', 'fire']
# 4288 units each with 20026 hit points with an attack that does 7 radiation damage at initiative 2
# ['name', 'Infection group 10', 'units', 4288, 'hp', 20026, 'dmg', 7, 'ini', 2, 'weak', [], 'immune', [], 'dmgtype', 'radiation']
# Immune system:
# Group 1 contains 3115 units
# Group 2 contains 3866 units
# Group 3 contains 40 units
# Group 4 contains 1923 units
# Group 5 contains 4033 units
# Group 6 contains 36 units
# Group 7 contains 2814 units
# Group 8 contains 217 units
# Group 9 contains 38 units
# Group 10 contains 5552 units
# Infection:
# Group 1 contains 263 units
# Group 2 contains 137 units
# Group 3 contains 2374 units
# Group 4 contains 1287 units
# Group 5 contains 43 units
# Group 6 contains 140 units
# Group 7 contains 3814 units
# Group 8 contains 3470 units
# Group 9 contains 394 units
# Group 10 contains 4288 units
#
# Infection group 6 would deal defending group 4 177240 damage
# Infection group 3 would deal defending group 3 161432 damage
# Infection group 8 would deal defending group 2 159620 damage
# Infection group 9 would deal defending group 5 64616 damage
# Infection group 5 would deal defending group 8 57921 damage
# Infection group 7 would deal defending group 7 57210 damage
# Infection group 2 would deal defending group 6 50279 damage
# Infection group 1 would deal defending group 9 48918 damage
# Infection group 4 would deal defending group 10 46332 damage
# Infection group 10 would deal defending group 1 30016 damage
# Immune system group 3 would deal defending group 3 177840 damage
# Immune system group 5 would deal defending group 8 177452 damage
# Immune system group 8 would deal defending group 5 149730 damage
# Immune system group 7 would deal defending group 1 118188 damage
# Immune system group 6 would deal defending group 6 114408 damage
# Immune system group 9 would deal defending group 9 55632 damage
# Immune system group 2 would deal defending group 7 54124 damage
# Immune system group 10 would deal defending group 10 33312 damage
# Immune system group 4 would deal defending group 2 19230 damage
# Immune system group 1 would deal defending group 4 12460 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Infection group 5 attacks Immune system group 8 killing 6 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 9 attacks Infection group 9 killing 1 units
# Immune system group 4 attacks Infection group 2 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 79 units
# Immune system group 2 attacks Infection group 7 killing 1 units
# Immune system group 10 attacks Infection group 10 killing 1 units
# Infection group 1 attacks Immune system group 9 killing 6 units
# Immune system group 8 attacks Infection group 5 killing 4 units
# Immune system group 1 attacks Infection group 4 killing 0 units
# Infection group 3 attacks Immune system group 3 killing 15 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Immune system group 6 attacks Infection group 6 killing 2 units
# Immune system group 3 attacks Infection group 3 killing 2 units
# Infection group 10 attacks Immune system group 1 killing 18 units
# Infection group 2 attacks Immune system group 6 killing 8 units
#
# Immune system:
# Group 1 contains 3097 units
# Group 2 contains 3842 units
# Group 3 contains 25 units
# Group 4 contains 1844 units
# Group 5 contains 4027 units
# Group 6 contains 28 units
# Group 7 contains 2807 units
# Group 8 contains 211 units
# Group 9 contains 32 units
# Group 10 contains 5540 units
# Infection:
# Group 1 contains 259 units
# Group 2 contains 137 units
# Group 3 contains 2372 units
# Group 4 contains 1287 units
# Group 5 contains 39 units
# Group 6 contains 138 units
# Group 7 contains 3813 units
# Group 8 contains 3467 units
# Group 9 contains 393 units
# Group 10 contains 4287 units
#
# Infection group 6 would deal defending group 4 174708 damage
# Infection group 3 would deal defending group 3 161296 damage
# Infection group 8 would deal defending group 2 159482 damage
# Infection group 9 would deal defending group 5 64452 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 5 would deal defending group 7 52533 damage
# Infection group 2 would deal defending group 9 50279 damage
# Infection group 1 would deal defending group 6 96348 damage
# Infection group 4 would deal defending group 10 46332 damage
# Infection group 10 would deal defending group 1 30009 damage
# Immune system group 5 would deal defending group 8 177188 damage
# Immune system group 8 would deal defending group 5 145590 damage
# Immune system group 7 would deal defending group 1 117894 damage
# Immune system group 3 would deal defending group 3 111150 damage
# Immune system group 2 would deal defending group 6 107576 damage
# Immune system group 9 would deal defending group 9 46848 damage
# Immune system group 6 would deal defending group 7 44492 damage
# Immune system group 10 would deal defending group 10 33240 damage
# Immune system group 4 would deal defending group 2 18440 damage
# Immune system group 1 would deal defending group 4 12388 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Infection group 5 attacks Immune system group 7 killing 6 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 9 attacks Infection group 9 killing 1 units
# Immune system group 4 attacks Infection group 2 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 78 units
# Immune system group 2 attacks Infection group 6 killing 2 units
# Immune system group 10 attacks Infection group 10 killing 1 units
# Infection group 1 attacks Immune system group 6 killing 15 units
# Immune system group 8 attacks Infection group 5 killing 4 units
# Immune system group 1 attacks Infection group 4 killing 0 units
# Infection group 3 attacks Immune system group 3 killing 15 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Immune system group 6 attacks Infection group 7 killing 0 units
# Immune system group 3 attacks Infection group 3 killing 1 units
# Infection group 10 attacks Immune system group 1 killing 18 units
# Infection group 2 attacks Immune system group 9 killing 6 units
#
# Immune system:
# Group 1 contains 3079 units
# Group 2 contains 3818 units
# Group 3 contains 10 units
# Group 4 contains 1766 units
# Group 5 contains 4021 units
# Group 6 contains 13 units
# Group 7 contains 2801 units
# Group 8 contains 205 units
# Group 9 contains 26 units
# Group 10 contains 5528 units
# Infection:
# Group 1 contains 255 units
# Group 2 contains 137 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 35 units
# Group 6 contains 136 units
# Group 7 contains 3813 units
# Group 8 contains 3464 units
# Group 9 contains 392 units
# Group 10 contains 4286 units
#
# Infection group 6 would deal defending group 4 172176 damage
# Infection group 3 would deal defending group 9 161228 damage
# Infection group 8 would deal defending group 2 159344 damage
# Infection group 9 would deal defending group 5 64288 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 2 would deal defending group 7 50279 damage
# Infection group 1 would deal defending group 6 94860 damage
# Infection group 5 would deal defending group 10 47145 damage
# Infection group 4 would deal defending group 1 46332 damage
# Infection group 10 would deal defending group 3 30002 damage
# Immune system group 5 would deal defending group 8 176924 damage
# Immune system group 8 would deal defending group 1 141450 damage
# Immune system group 7 would deal defending group 5 117642 damage
# Immune system group 2 would deal defending group 6 106904 damage
# Immune system group 9 would deal defending group 9 38064 damage
# Immune system group 10 would deal defending group 3 33168 damage
# Immune system group 3 would deal defending group 2 44460 damage
# Immune system group 6 would deal defending group 7 20657 damage
# Immune system group 4 would deal defending group 4 17660 damage
# Immune system group 1 would deal defending group 10 12316 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 1 killing 29 units
# Infection group 5 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 5 killing 3 units
# Immune system group 9 attacks Infection group 9 killing 1 units
# Immune system group 4 attacks Infection group 4 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 77 units
# Immune system group 2 attacks Infection group 6 killing 2 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Infection group 1 attacks Immune system group 6 killing 13 units
# Immune system group 8 attacks Infection group 1 killing 4 units
# Immune system group 1 attacks Infection group 10 killing 0 units
# Infection group 3 attacks Immune system group 9 killing 20 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Immune system group 6 attacks Infection group 7 killing 0 units
# Immune system group 3 attacks Infection group 2 killing 1 units
# Infection group 10 attacks Immune system group 3 killing 2 units
# Infection group 2 attacks Immune system group 7 killing 6 units
#
# Immune system:
# Group 1 contains 3050 units
# Group 2 contains 3794 units
# Group 3 contains 8 units
# Group 4 contains 1689 units
# Group 5 contains 4015 units
# Group 7 contains 2795 units
# Group 8 contains 199 units
# Group 9 contains 6 units
# Group 10 contains 5516 units
# Infection:
# Group 1 contains 251 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 32 units
# Group 6 contains 134 units
# Group 7 contains 3813 units
# Group 8 contains 3461 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 6 would deal defending group 4 169644 damage
# Infection group 3 would deal defending group 3 161228 damage
# Infection group 8 would deal defending group 2 159206 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 2 would deal defending group 7 49912 damage
# Infection group 1 would deal defending group 10 46686 damage
# Infection group 4 would deal defending group 1 46332 damage
# Infection group 5 would deal defending group 9 43104 damage
# Immune system group 5 would deal defending group 8 176660 damage
# Immune system group 8 would deal defending group 1 137310 damage
# Immune system group 7 would deal defending group 5 117390 damage
# Immune system group 2 would deal defending group 6 106232 damage
# Immune system group 10 would deal defending group 3 33096 damage
# Immune system group 3 would deal defending group 2 35568 damage
# Immune system group 4 would deal defending group 9 16890 damage
# Immune system group 1 would deal defending group 7 12200 damage
# Immune system group 9 would deal defending group 4 8784 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 1 killing 29 units
# Infection group 5 attacks Immune system group 9 killing 5 units
# Immune system group 7 attacks Infection group 5 killing 3 units
# Immune system group 9 attacks Infection group 4 killing 0 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 76 units
# Immune system group 2 attacks Infection group 6 killing 2 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Infection group 1 attacks Immune system group 10 killing 12 units
# Immune system group 8 attacks Infection group 1 killing 4 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 3 killing 8 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Immune system group 3 attacks Infection group 2 killing 0 units
# Infection group 2 attacks Immune system group 7 killing 6 units
#
# Immune system:
# Group 1 contains 3021 units
# Group 2 contains 3770 units
# Group 4 contains 1613 units
# Group 5 contains 4009 units
# Group 7 contains 2789 units
# Group 8 contains 193 units
# Group 9 contains 1 units
# Group 10 contains 5504 units
# Infection:
# Group 1 contains 247 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 29 units
# Group 6 contains 132 units
# Group 7 contains 3813 units
# Group 8 contains 3458 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 6 would deal defending group 4 167112 damage
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 159068 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 2 would deal defending group 7 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Infection group 1 would deal defending group 9 45942 damage
# Immune system group 5 would deal defending group 8 176396 damage
# Immune system group 8 would deal defending group 1 133170 damage
# Immune system group 7 would deal defending group 5 117138 damage
# Immune system group 2 would deal defending group 6 105560 damage
# Immune system group 10 would deal defending group 3 33024 damage
# Immune system group 4 would deal defending group 9 16130 damage
# Immune system group 1 would deal defending group 7 12084 damage
# Immune system group 9 would deal defending group 2 1464 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 5 killing 3 units
# Immune system group 9 attacks Infection group 2 killing 0 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 74 units
# Immune system group 2 attacks Infection group 6 killing 2 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Infection group 1 attacks Immune system group 9 killing 1 units
# Immune system group 8 attacks Infection group 1 killing 4 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 7 killing 6 units
#
# Immune system:
# Group 1 contains 2920 units
# Group 2 contains 3746 units
# Group 4 contains 1539 units
# Group 5 contains 4003 units
# Group 7 contains 2783 units
# Group 8 contains 187 units
# Group 10 contains 5492 units
# Infection:
# Group 1 contains 243 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 26 units
# Group 6 contains 130 units
# Group 7 contains 3813 units
# Group 8 contains 3455 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 6 would deal defending group 4 164580 damage
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 158930 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 2 would deal defending group 7 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 176132 damage
# Immune system group 8 would deal defending group 1 129030 damage
# Immune system group 7 would deal defending group 5 116886 damage
# Immune system group 2 would deal defending group 6 104888 damage
# Immune system group 10 would deal defending group 3 32952 damage
# Immune system group 4 would deal defending group 9 15390 damage
# Immune system group 1 would deal defending group 7 11680 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 5 killing 3 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 73 units
# Immune system group 2 attacks Infection group 6 killing 2 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 1 killing 4 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 7 killing 6 units
#
# Immune system:
# Group 1 contains 2819 units
# Group 2 contains 3722 units
# Group 4 contains 1466 units
# Group 5 contains 3997 units
# Group 7 contains 2777 units
# Group 8 contains 181 units
# Group 10 contains 5480 units
# Infection:
# Group 1 contains 239 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 23 units
# Group 6 contains 128 units
# Group 7 contains 3813 units
# Group 8 contains 3452 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 6 would deal defending group 4 162048 damage
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 158792 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 2 would deal defending group 7 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 175868 damage
# Immune system group 8 would deal defending group 1 124890 damage
# Immune system group 7 would deal defending group 5 116634 damage
# Immune system group 2 would deal defending group 6 104216 damage
# Immune system group 10 would deal defending group 3 32880 damage
# Immune system group 4 would deal defending group 9 14660 damage
# Immune system group 1 would deal defending group 7 11276 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 5 killing 3 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 72 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 1 killing 4 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 7 killing 6 units
#
# Immune system:
# Group 1 contains 2718 units
# Group 2 contains 3698 units
# Group 4 contains 1394 units
# Group 5 contains 3991 units
# Group 7 contains 2771 units
# Group 8 contains 175 units
# Group 10 contains 5468 units
# Infection:
# Group 1 contains 235 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 20 units
# Group 6 contains 127 units
# Group 7 contains 3813 units
# Group 8 contains 3449 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 6 would deal defending group 4 160782 damage
# Infection group 8 would deal defending group 2 158654 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 2 would deal defending group 7 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 175604 damage
# Immune system group 8 would deal defending group 1 120750 damage
# Immune system group 7 would deal defending group 5 116382 damage
# Immune system group 2 would deal defending group 6 103544 damage
# Immune system group 10 would deal defending group 3 32808 damage
# Immune system group 4 would deal defending group 9 13940 damage
# Immune system group 1 would deal defending group 7 10872 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 5 killing 3 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 72 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 1 killing 4 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 7 killing 6 units
#
# Immune system:
# Group 1 contains 2617 units
# Group 2 contains 3674 units
# Group 4 contains 1322 units
# Group 5 contains 3985 units
# Group 7 contains 2765 units
# Group 8 contains 169 units
# Group 10 contains 5456 units
# Infection:
# Group 1 contains 231 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 17 units
# Group 6 contains 126 units
# Group 7 contains 3813 units
# Group 8 contains 3446 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 6 would deal defending group 4 159516 damage
# Infection group 8 would deal defending group 2 158516 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 8 57195 damage
# Infection group 2 would deal defending group 7 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 175340 damage
# Immune system group 8 would deal defending group 1 116610 damage
# Immune system group 7 would deal defending group 5 116130 damage
# Immune system group 2 would deal defending group 6 102872 damage
# Immune system group 10 would deal defending group 3 32736 damage
# Immune system group 4 would deal defending group 9 13220 damage
# Immune system group 1 would deal defending group 7 10468 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 8 killing 6 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 5 killing 3 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 71 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 1 killing 3 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 7 killing 6 units
#
# Immune system:
# Group 1 contains 2516 units
# Group 2 contains 3650 units
# Group 4 contains 1251 units
# Group 5 contains 3979 units
# Group 7 contains 2759 units
# Group 8 contains 163 units
# Group 10 contains 5444 units
# Infection:
# Group 1 contains 228 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 14 units
# Group 6 contains 125 units
# Group 7 contains 3813 units
# Group 8 contains 3443 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 158378 damage
# Infection group 6 would deal defending group 4 158250 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 175076 damage
# Immune system group 7 would deal defending group 1 115878 damage
# Immune system group 8 would deal defending group 5 112470 damage
# Immune system group 2 would deal defending group 6 102200 damage
# Immune system group 10 would deal defending group 3 32664 damage
# Immune system group 4 would deal defending group 9 12510 damage
# Immune system group 1 would deal defending group 7 10064 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 70 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 5 killing 3 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 2415 units
# Group 2 contains 3626 units
# Group 4 contains 1181 units
# Group 5 contains 3973 units
# Group 7 contains 2752 units
# Group 8 contains 158 units
# Group 10 contains 5432 units
# Infection:
# Group 1 contains 224 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 11 units
# Group 6 contains 124 units
# Group 7 contains 3813 units
# Group 8 contains 3440 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 158240 damage
# Infection group 6 would deal defending group 4 156984 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 174812 damage
# Immune system group 7 would deal defending group 1 115584 damage
# Immune system group 8 would deal defending group 5 109020 damage
# Immune system group 2 would deal defending group 6 101528 damage
# Immune system group 10 would deal defending group 3 32592 damage
# Immune system group 4 would deal defending group 9 11810 damage
# Immune system group 1 would deal defending group 7 9660 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 70 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 5 killing 3 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 2314 units
# Group 2 contains 3602 units
# Group 4 contains 1111 units
# Group 5 contains 3967 units
# Group 7 contains 2745 units
# Group 8 contains 153 units
# Group 10 contains 5420 units
# Infection:
# Group 1 contains 220 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 8 units
# Group 6 contains 123 units
# Group 7 contains 3813 units
# Group 8 contains 3437 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 158102 damage
# Infection group 6 would deal defending group 4 155718 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 174548 damage
# Immune system group 7 would deal defending group 1 115290 damage
# Immune system group 8 would deal defending group 5 105570 damage
# Immune system group 2 would deal defending group 6 100856 damage
# Immune system group 10 would deal defending group 3 32520 damage
# Immune system group 4 would deal defending group 9 11110 damage
# Immune system group 1 would deal defending group 7 9256 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 69 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 5 killing 3 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 2213 units
# Group 2 contains 3578 units
# Group 4 contains 1042 units
# Group 5 contains 3961 units
# Group 7 contains 2738 units
# Group 8 contains 148 units
# Group 10 contains 5408 units
# Infection:
# Group 1 contains 216 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 5 units
# Group 6 contains 122 units
# Group 7 contains 3813 units
# Group 8 contains 3434 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 157964 damage
# Infection group 6 would deal defending group 4 154452 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 174284 damage
# Immune system group 7 would deal defending group 1 114996 damage
# Immune system group 8 would deal defending group 5 102120 damage
# Immune system group 2 would deal defending group 6 100184 damage
# Immune system group 10 would deal defending group 3 32448 damage
# Immune system group 4 would deal defending group 9 10420 damage
# Immune system group 1 would deal defending group 7 8852 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 69 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 5 killing 3 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 2112 units
# Group 2 contains 3554 units
# Group 4 contains 973 units
# Group 5 contains 3955 units
# Group 7 contains 2731 units
# Group 8 contains 143 units
# Group 10 contains 5396 units
# Infection:
# Group 1 contains 212 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 5 contains 2 units
# Group 6 contains 121 units
# Group 7 contains 3813 units
# Group 8 contains 3431 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 157826 damage
# Infection group 6 would deal defending group 4 153186 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 174020 damage
# Immune system group 7 would deal defending group 1 114702 damage
# Immune system group 2 would deal defending group 6 99512 damage
# Immune system group 8 would deal defending group 5 98670 damage
# Immune system group 10 would deal defending group 3 32376 damage
# Immune system group 4 would deal defending group 9 9730 damage
# Immune system group 1 would deal defending group 7 8448 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 4 attacks Infection group 9 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 68 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 5 killing 2 units
# Immune system group 1 attacks Infection group 7 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 2011 units
# Group 2 contains 3530 units
# Group 4 contains 905 units
# Group 5 contains 3949 units
# Group 7 contains 2724 units
# Group 8 contains 138 units
# Group 10 contains 5384 units
# Infection:
# Group 1 contains 208 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 120 units
# Group 7 contains 3813 units
# Group 8 contains 3428 units
# Group 9 contains 391 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 157688 damage
# Infection group 6 would deal defending group 4 151920 damage
# Infection group 9 would deal defending group 5 64124 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 173756 damage
# Immune system group 7 would deal defending group 1 114408 damage
# Immune system group 2 would deal defending group 6 98840 damage
# Immune system group 8 would deal defending group 9 47610 damage
# Immune system group 10 would deal defending group 3 32304 damage
# Immune system group 4 would deal defending group 7 9050 damage
# Immune system group 1 would deal defending group 2 8044 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 4 units
# Immune system group 4 attacks Infection group 7 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 68 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 9 killing 1 units
# Immune system group 1 attacks Infection group 2 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 1910 units
# Group 2 contains 3506 units
# Group 4 contains 837 units
# Group 5 contains 3943 units
# Group 7 contains 2717 units
# Group 8 contains 133 units
# Group 10 contains 5372 units
# Infection:
# Group 1 contains 204 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 119 units
# Group 7 contains 3813 units
# Group 8 contains 3425 units
# Group 9 contains 390 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 157550 damage
# Infection group 6 would deal defending group 4 150654 damage
# Infection group 9 would deal defending group 5 63960 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 173492 damage
# Immune system group 7 would deal defending group 1 114114 damage
# Immune system group 2 would deal defending group 6 98168 damage
# Immune system group 8 would deal defending group 9 45885 damage
# Immune system group 10 would deal defending group 3 32232 damage
# Immune system group 4 would deal defending group 7 8370 damage
# Immune system group 1 would deal defending group 2 7640 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 3 units
# Immune system group 4 attacks Infection group 7 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 67 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 9 killing 1 units
# Immune system group 1 attacks Infection group 2 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 1809 units
# Group 2 contains 3482 units
# Group 4 contains 770 units
# Group 5 contains 3937 units
# Group 7 contains 2710 units
# Group 8 contains 128 units
# Group 10 contains 5360 units
# Infection:
# Group 1 contains 201 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 118 units
# Group 7 contains 3813 units
# Group 8 contains 3422 units
# Group 9 contains 389 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 157412 damage
# Infection group 6 would deal defending group 4 149388 damage
# Infection group 9 would deal defending group 5 63796 damage
# Infection group 7 would deal defending group 7 57195 damage
# Infection group 2 would deal defending group 8 49912 damage
# Infection group 4 would deal defending group 10 46332 damage
# Immune system group 5 would deal defending group 8 173228 damage
# Immune system group 7 would deal defending group 1 113820 damage
# Immune system group 2 would deal defending group 6 97496 damage
# Immune system group 8 would deal defending group 9 44160 damage
# Immune system group 10 would deal defending group 3 32160 damage
# Immune system group 4 would deal defending group 7 7700 damage
# Immune system group 1 would deal defending group 2 7236 damage
#
# Infection group 9 attacks Immune system group 5 killing 6 units
# Infection group 7 attacks Immune system group 7 killing 7 units
# Infection group 8 attacks Immune system group 2 killing 24 units
# Infection group 4 attacks Immune system group 10 killing 12 units
# Immune system group 7 attacks Infection group 1 killing 3 units
# Immune system group 4 attacks Infection group 7 killing 0 units
# Infection group 6 attacks Immune system group 4 killing 66 units
# Immune system group 2 attacks Infection group 6 killing 1 units
# Immune system group 10 attacks Infection group 3 killing 0 units
# Immune system group 8 attacks Infection group 9 killing 1 units
# Immune system group 1 attacks Infection group 2 killing 0 units
# Infection group 3 attacks Immune system group 1 killing 101 units
# Immune system group 5 attacks Infection group 8 killing 3 units
# Infection group 2 attacks Immune system group 8 killing 5 units
#
# Immune system:
# Group 1 contains 1708 units
# Group 2 contains 3458 units
# Group 4 contains 704 units
# Group 5 contains 3931 units
# Group 7 contains 2703 units
# Group 8 contains 123 units
# Group 10 contains 5348 units
# Infection:
# Group 1 contains 198 units
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 117 units
# Group 7 contains 3813 units
# Group 8 contains 3419 units
# Group 9 contains 388 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 1 161228 damage
# Infection group 8 would deal defending group 2 157274 damage
# ...
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 210 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 9240 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 203 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 8932 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 196 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 8624 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 189 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 8316 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 182 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 8008 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 175 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 7700 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 168 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 7392 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 161 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 7084 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 154 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 6776 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 147 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 6468 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 140 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 6160 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 133 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 5852 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 126 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 5544 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 119 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 5236 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 112 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 4928 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 105 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 4620 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 98 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 4312 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 91 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 4004 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 84 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 3696 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 77 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 3388 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 70 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 3080 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 63 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 2772 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 56 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 2464 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 49 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 2156 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 42 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 1848 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 35 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 1540 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 28 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 1232 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 21 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 924 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 14 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 616 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units
#
# Immune system:
# Group 5 contains 7 units
# Infection:
# Group 2 contains 136 units
# Group 3 contains 2371 units
# Group 4 contains 1287 units
# Group 6 contains 49 units
# Group 7 contains 3782 units
# Group 8 contains 2597 units
# Group 9 contains 346 units
# Group 10 contains 4286 units
#
# Infection group 3 would deal defending group 5 80614 damage
# Immune system group 5 would deal defending group 8 308 damage
#
# Infection group 3 attacks Immune system group 5 killing 7 units
# Immune system group 5 attacks Infection group 8 killing 0 units

# %%
# results of the run without boosting:
print(infecT.final())
print(immuT.final())
# Out:
# Infection remaining units 14854
# Immune system remaining units 0

# %%
# hack to overwrite print function
real_print = print
def print(*args, **kwargs):
    pass
    
for boost in range(60,80):
    print(boost)
    immuT = Team(immu, "Immune system", boost)
    infecT = Team(infec, "Infection")
    last_units = 0

    while immuT.get_units() > 0 and infecT.get_units() > 0:
        # target phase
        infecT.target_selection(immuT)
        immuT.target_selection(infecT)
        
        # attack phase
        # get team with biggest ini first
        tgroups = [*infecT.groups.values(), *immuT.groups.values()]
        tgroups = sorted(tgroups, key=lambda g: g.ini, reverse=True)
        for group in tgroups:
            group.attack()
        
        # cleanup phase: delete groups with 0 units
        infecT.cleanup()
        immuT.cleanup()

        units = infecT.get_units() + immuT.get_units()
        if last_units == units:
            real_print("no progress made, exiting this try")
            break
        last_units = units

    real_print(boost, infecT.final(), immuT.final())
# Out:
# 60 Infection remaining units 2574 Immune system remaining units 0
# 61 Infection remaining units 2198 Immune system remaining units 0
# 62 Infection remaining units 1791 Immune system remaining units 0
# 63 Infection remaining units 1423 Immune system remaining units 0
# 64 Infection remaining units 964 Immune system remaining units 0
# 65 Infection remaining units 566 Immune system remaining units 0
# 66 Infection remaining units 479 Immune system remaining units 0
# 67 Infection remaining units 399 Immune system remaining units 0
# 68 Infection remaining units 309 Immune system remaining units 0
# no progress made, exiting this try
# 69 Infection remaining units 197 Immune system remaining units 3187
# 70 Infection remaining units 0 Immune system remaining units 3467
# 71 Infection remaining units 0 Immune system remaining units 3877
# 72 Infection remaining units 0 Immune system remaining units 4107
# 73 Infection remaining units 0 Immune system remaining units 4405
# 74 Infection remaining units 0 Immune system remaining units 4717
# 75 Infection remaining units 0 Immune system remaining units 4943
# 76 Infection remaining units 0 Immune system remaining units 5116
# 77 Infection remaining units 0 Immune system remaining units 5277
# 78 Infection remaining units 0 Immune system remaining units 5447
# 79 Infection remaining units 0 Immune system remaining units 5629
