# %%
#ex1 
a = "..."
#a = "dabAcCaCBAcCcaDA" #demo sequence
for _ in range(1000):
    for i in "abcdefghijklmnopqrstuvwxyz":
        a=a.replace(i+i.upper(), "")
        a=a.replace(i.upper()+i, "")
print(len(a))
# Out:
# 10878

# %%
#ex2
for j in "abcdefghijklmnopqrstuvwxyz":
    b=a.replace(j,"").replace(j.upper(),"")
    for _ in range(1000):
        for i in "abcdefghijklmnopqrstuvwxyz":
            b=b.replace(i+i.upper(), "")
            b=b.replace(i.upper()+i, "")
    print(j, len(b))
# Out:
# a 10408
# b 10412
# c 10460
# d 10438
# e 10474
# f 6874
# g 10508
# h 10500
# i 10440
# j 10426
# k 10418
# l 10420
# m 10498
# n 10406
# o 10464
# p 10396
# q 10470
# r 10386
# s 10424
# t 10442
# u 10454
# v 10500
# w 10480
# x 10400
# y 10472
# z 10460
